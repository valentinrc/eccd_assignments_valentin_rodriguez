# %% [markdown]
# # Objective
#
# The objective of this notebook is get hands-on experience on cleaning a "dirty" dataset.
# Often, datasets are created from "free-text" fields. In free-text fields, data validation is not enforced and as a result, many conventions co-exist within the same column of data.
# Dirty data can also ocurr when collection information from different sources. If these sources use different conventions to represent such data, additional efforts are required to homogenize it at a later stage.

# %% [markdown]
# ## Setup

# %%
# !pip install -q eccd_datasets pygradus

# %%
STUDENT_NAME = "jose_valetin_rodriguez"
COURSE_NAME = "eccd-oct23"
EXERCISE_NAME = "cleaning-a-dataset"

# %%
import pandas as pd
import numpy as np
from eccd_datasets import load_lingerie
from pygradus import create_exercise, check_solution

# %%
datasets = load_lingerie()

# %%
datasets.keys()
# Out:
# dict_keys(['ae_com', 'amazon_com', 'btemptd_com', 'calvinklein_com', 'hankypanky_com', 'macys_com', 'shop_nordstrom_com', 'us_topshop_com', 'victoriassecret_com'])

# %% [markdown]
# ## The different datasets on their own

# %%
datasets["ae_com"].head()
# Out:
#                        product_name        mrp      price  \
# 0  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 1  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 2  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 3  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
# 4  Aerie Everyday Loves Lace Cheeky  12.50 USD  12.50 USD
#
#                                              pdp_url brand_name  \
# 0  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 1  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 2  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 3  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
# 4  https://www.ae.com/aerie-everyday-loves-lace-c...      AERIE
#
#   product_category retailer  \
# 0         Cheekies    Ae US
# 1         Cheekies    Ae US
# 2         Cheekies    Ae US
# 3         Cheekies    Ae US
# 4         Cheekies    Ae US
#
#                                          description  rating  review_count  \
# 0  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 1  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 2  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 3  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
# 4  Introducing Everyday Loves™: Made with love. E...     5.0           8.0
#
#                                     style_attributes  \
# 0  ["Soft lace with the right amount of stretch",...
# 1  ["Soft lace with the right amount of stretch",...
# 2  ["Soft lace with the right amount of stretch",...
# 3  ["Soft lace with the right amount of stretch",...
# 4  ["Soft lace with the right amount of stretch",...
#
#                           total_sizes                      available_size  \
# 0  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 1  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 2  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 3  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
# 4  ["XS", "S", "M", "L", "XL", "XXL"]  ["XS", "S", "M", "L", "XL", "XXL"]
#
#           color
# 0  Rugged Green
# 1  Natural Nude
# 2    True Black
# 3         White
# 4    Royal Navy

# %%
datasets["victoriassecret_com"].head()
# Out:
#                          product_name      mrp    price  \
# 0  Very Sexy Strappy Lace Thong Panty  $14.50   $14.50
# 1  Very Sexy Strappy Lace Thong Panty  $14.50   $14.50
# 2  Very Sexy Strappy Lace Thong Panty  $14.50   $14.50
# 3  Very Sexy Strappy Lace Thong Panty  $14.50   $14.50
# 4  Very Sexy Strappy Lace Thong Panty  $14.50   $14.50
#
#                                              pdp_url         brand_name  \
# 0  https://www.victoriassecret.com/panties/shop-a...  Victoria's Secret
# 1  https://www.victoriassecret.com/panties/shop-a...  Victoria's Secret
# 2  https://www.victoriassecret.com/panties/shop-a...  Victoria's Secret
# 3  https://www.victoriassecret.com/panties/shop-a...  Victoria's Secret
# 4  https://www.victoriassecret.com/panties/shop-a...  Victoria's Secret
#
#            product_category            retailer  \
# 0  Strappy Lace Thong Panty  Victoriassecret US
# 1  Strappy Lace Thong Panty  Victoriassecret US
# 2  Strappy Lace Thong Panty  Victoriassecret US
# 3  Strappy Lace Thong Panty  Victoriassecret US
# 4  Strappy Lace Thong Panty  Victoriassecret US
#
#                                          description  rating  review_count  \
# 0  Lots of cheek peek, pretty lace, a strappy bac...     NaN           NaN
# 1  Lots of cheek peek, pretty lace, a strappy bac...     NaN           NaN
# 2  Lots of cheek peek, pretty lace, a strappy bac...     NaN           NaN
# 3  Lots of cheek peek, pretty lace, a strappy bac...     NaN           NaN
# 4  Lots of cheek peek, pretty lace, a strappy bac...     NaN           NaN
#
#    style_attributes                  total_sizes available_size        color
# 0               NaN  ["XS", "S", "M", "L", "XL"]              S  peach melba
# 1               NaN  ["XS", "S", "M", "L", "XL"]              S        black
# 2               NaN  ["XS", "S", "M", "L", "XL"]              S    plum dust
# 3               NaN  ["XS", "S", "M", "L", "XL"]              S  ensign blue
# 4               NaN  ["XS", "S", "M", "L", "XL"]              S  fair orchid

# %% [markdown]
# ### Joining all the datasets into one

# %%
df = pd.concat(datasets.values())

# %%
df.shape
# Out:
# (613143, 14)

# %% [markdown]
# # Calculating statistics on the dataset

# %% [markdown]
# ## Unifying Victoria's Secret

# %%
def unify_victoria_secret(df):
    """
    We want that all brands that are related to Victoria's Secret
    have `victoria's secret` as their brand instead of what they
    currently have.
    """
    df = df.copy()
    new_string = "victoria's secret"
    # Write your code here
    df['brand_name'] = df['brand_name'].str.replace(r'.*Victoria.*', new_string, case=False, regex=True)
   # df.loc[df['retailer'] == "Victoriassecret US", 'brand_name'] = new_string
    return df

# %%
df_unified = unify_victoria_secret(df)

# %%
answer_victoria_secret =df_unified[df_unified["brand_name"] == "victoria's secret"].shape[0]
print(answer_victoria_secret)
# Out:
# 453453

# %%
df_unified[df_unified['product_name'] == "'Retro' Thong"].head()
# Out:
#       product_name            mrp          price  \
# 298  'Retro' Thong  $23.00–$25.00  $23.00–$25.00
# 299  'Retro' Thong  $23.00–$25.00  $23.00–$25.00
# 300  'Retro' Thong  $23.00–$25.00  $23.00–$25.00
# 301  'Retro' Thong  $23.00–$25.00  $23.00–$25.00
# 302  'Retro' Thong  $23.00–$25.00  $23.00–$25.00
#
#                                                pdp_url   brand_name  \
# 298  http://shop.nordstrom.com/s/hanky-panky-retro-...  HANKY PANKY
# 299  http://shop.nordstrom.com/s/hanky-panky-retro-...  HANKY PANKY
# 300  http://shop.nordstrom.com/s/hanky-panky-retro-...  HANKY PANKY
# 301  http://shop.nordstrom.com/s/hanky-panky-retro-...  HANKY PANKY
# 302  http://shop.nordstrom.com/s/hanky-panky-retro-...  HANKY PANKY
#
#     product_category      retailer  \
# 298  Women's Panties  Nordstrom US
# 299  Women's Panties  Nordstrom US
# 300  Women's Panties  Nordstrom US
# 301  Women's Panties  Nordstrom US
# 302  Women's Panties  Nordstrom US
#
#                                            description  rating  review_count  \
# 298  An extra-wide waistband gives a supersoft stre...     4.8         109.0
# 299  An extra-wide waistband gives a supersoft stre...     4.8         109.0
# 300  An extra-wide waistband gives a supersoft stre...     4.8         109.0
# 301  An extra-wide waistband gives a supersoft stre...     4.8         109.0
# 302  An extra-wide waistband gives a supersoft stre...     4.8         109.0
#
#                                       style_attributes total_sizes  \
# 298  ["Neon colors are brighter in person.", "100% ...       [nil]
# 299  ["Neon colors are brighter in person.", "100% ...       [nil]
# 300  ["Neon colors are brighter in person.", "100% ...       [nil]
# 301  ["Neon colors are brighter in person.", "100% ...       [nil]
# 302  ["Neon colors are brighter in person.", "100% ...       [nil]
#
#     available_size             color
# 298          [nil]             Black
# 299          [nil]       Marshmallow
# 300          [nil]              Chai
# 301          [nil]           Granite
# 302          [nil]  Nightshadow Blue

# %% [markdown]
# ## Cleaning up the price
#
# In this sectino we are going to transform the `price` column into a float column in USD dolars.
#
# For this, be careful of the different formats in the data.
#
# For simplicity, you might assume that all the prices are in USD dolars, regarding of the symbol of the currency used.

# %%
valores_unicos_price = df_unified['price'].unique()

# %%
# Imprimir en lotes de 20 elementos
for i in range(0, len(valores_unicos_price), 20):
    print(valores_unicos_price[i:i+20])
# Out:
# ['12.50 USD' '9.50 USD' '7.50 USD' '14.50 USD' '34.96 USD' '31.46 USD'
#  '20.96 USD' '16.06 USD' '27.96 USD' '18.86 USD' '48.99 USD' '17.46 USD'
#  '23.06 USD' '24.46 USD' '25.86 USD' '51.09 USD' '10.15 USD' '46.89 USD'
#  '10.85 USD' '26.95 USD']
# ['8.05 USD' '25.55 USD' '26.97 USD' '23.97 USD' '22.47 USD' '17.47 USD'
#  '29.97 USD' '14.97 USD' '13.47 USD' '20.97 USD' '17.97 USD' '24.97 USD'
#  '11.47 USD' '12.47 USD' '19.77 USD' '22.17 USD' '19.97 USD' '3.99 USD'
#  '16.17 USD' '13.77 USD']
00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$10.00'
#  '\xa0$5.00' '\xa0$70.00' '\xa0$28.00']
# ['\xa0$90.00' '\xa0$60.00' '\xa0$4.00'
#  '\xa0$35.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$15.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00'
#  '\xa0$110.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$10.00'
#  '\xa0$30.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$20.00'
#  '\xa0$7.00' '\xa0$68.00'
#  '\xa0$35.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$24.00'
#  '\xa0$75.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$24.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$65.00' '\xa0$48.00' '\xa0$50.00' '\xa0$58.00'
#  '\xa0$38.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00']
# ['\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$6.00'
#  '\xa0$12.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$4.00'
#  '\xa0$10.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$4.00'
#  '\xa0$20.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$15.00'
#  '\xa0$17.50' '\xa0$24.00' '\xa0$6.00' '\xa0$2.00'
#  '\xa0$26.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00'
#  '\xa0$45.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$12.00'
#  '\xa0$46.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$15.00'
#  '\xa0$30.00\n\t\t\t\t\t            \t\t\t\t\t\t\t\t            \t\t\t\t\t            \t\t\t\n\t\t\t\t\t            \t\t\n\t\t\t\t\t\t            \t\t\t\tNow\xa0$8.00'
#  '$68.50 ' '$8.50 ' '$62.50 ' '$55.50 ' '$66.50 ' '$5.99 ' '$46.50 '
#  '$2.99 ']
# ['$12.95 ' '$69.50 ' '₡24.769' '₡25.935' 'Rp412.118' '$27.95 ' '$16.95 '
#  '$48.95 ' 'Rp116.911' 'Rp474.522' 'Rp543.294' 'Rp343.857']

# %%
import pandas as pd
import re

def clean_price(df):
    """
    In this function, we will transform the
    `price` column into a column of floats.
    In case a product has more than one price,
    return the lowest one.
    """

    # Extract numerical values from the 'price' column
    df['price'] = df['price'].apply(lambda x: re.search(r'\d+\.\d+', str(x)).group() if re.search(r'\d+\.\d+', str(x)) else None)

    # Convert the 'price' column to floats
    df['price'] = df['price'].apply(lambda x: float(x) if x is not None else None)

    # If there are multiple prices, keep the lowest one
    df['price'] = df.groupby('product_id')['price'].transform('min')

    return df

# %%
'''def clean_price(df):
    """
    In this function we will transform the
    `price` column into a column of floats.
    In case a product has more than one price,
    return the lowest one.
    """

    # Write your code here
    # Copiar el DataFrame original para no modificarlo directamente
    cleaned_df = df.copy()

    # Separar los precios múltiples y quedarse con el valor más bajo
    def clean_and_convert(x):
        if isinstance(x, list):
            prices = []
            for val in x:
                val = val.replace('USD', '').replace('$', '').strip()
                if '–' in val:
                    range_prices = val.split('–')
                    valid_range_prices = [v for v in range_prices if v.replace('.', '', 1).isdigit()]
                    prices.extend(valid_range_prices)
                elif val.replace('.', '', 1).isdigit():
                    prices.append(val)
            if prices:
                return min(map(float, prices))
            else:
                return 0.0  # No valid prices found
        else:
            try:
                val = x.replace('USD', '').replace('$', '').strip()
                if val.replace('.', '', 1).isdigit():
                    return float(val)
                else:
                    return 0.0
            except ValueError:
                return 0.0  # Handle non-numeric values

    cleaned_df['price'] = cleaned_df['price'].str.split('–').apply(clean_and_convert)

    return cleaned_df

# %%
df_clean = clean_price(df_unified)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-38fdeb72255b> in <cell line: 1>()
# ----> 1 df_clean = clean_price(df_unified)
#
# <ipython-input-42-96e3fc2c9070> in clean_price(df)
#      17
#      18     # If there are multiple prices, keep the lowest one
# ---> 19     df['price'] = df.groupby('product_id')['price'].transform('min')
#      20
#      21     return df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
#     966                 obj,
#     967                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     886                 in_axis, level, gpr = False, gpr, None
#     887             else:
# --> 888                 raise KeyError(gpr)
#     889         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     890             # Add key to exclusions
#
# KeyError: 'product_id'

# %%
df_clean.to_csv('hola.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-7898b983c739> in <cell line: 1>()
# ----> 1 df_clean.to_csv('hola.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315         libwriters.write_csv_rows(
#     316             data,
#     317             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
# Supongamos que ya tienes los valores únicos en la variable unique_prices
unique_prices = df_clean['price'].unique()

# Crear un DataFrame con los valores únicos
unique_prices_df = pd.DataFrame(unique_prices, columns=['Unique_Price'])

# Guardar el DataFrame en un archivo Excel
unique_prices_df.to_excel('valores_unicos.xlsx', index=False)

# %%
answer_unified_price_sum = df_clean["price"].sum()
print(answer_unified_price_sum)
# Out:
# 20043064.67

# %%
def low_high_product_mean(df):
    """
    Finally, we will calculate `product_category` with the lowest and highest mean price
    for the brand Victoria's Secret.
    """

    # Write your code here

    # Filtrar las filas para obtener solo las de la marca "Victoria's Secret"
    victorias_secret_df = df[df["brand_name"] == "victoria's secret"]

    # Agrupar por la columna 'product_category' y calcular la media del precio
    category_means = victorias_secret_df.groupby('product_category')['price'].mean()

    # Encontrar la categoría con el precio promedio más bajo
    lowest_mean= category_means.idxmin()

    # Encontrar la categoría con el precio promedio más alto
    highest_mean = category_means.idxmax()

    # Retornar las categorías con el precio promedio más bajo y más alto
    return lowest_mean, highest_mean

# %%
lowest_mean, highest_mean = low_high_product_mean(df_clean)
assert np.allclose(lowest_mean, 3.6203030303030)
print("highest_mean", highest_mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-a8f5bf0da668> in <cell line: 2>()
#       1 lowest_mean, highest_mean = low_high_product_mean(df_clean)
# ----> 2 assert np.allclose(lowest_mean, 3.6203030303030)
#       3 print("highest_mean", highest_mean)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in allclose(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2263
#    2264     """
# -> 2265     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2266     return bool(res)
#    2267
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in isclose(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2370         y = asanyarray(y, dtype=dt)
#    2371
# -> 2372     xfin = isfinite(x)
#    2373     yfin = isfinite(y)
#    2374     if all(xfin) and all(yfin):
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
proposed_solution = {
'attempt': {
    'course_name': COURSE_NAME,
    'exercise_name': EXERCISE_NAME,
    'username': STUDENT_NAME,
},
'task_attempts': [
         {
            "name": "victoria secret",
            "answer": str(answer_victoria_secret),
         },
         {
            "name": "price unification",
            "answer": str(answer_unified_price_sum),
         },
         {
            "name": "highest mean",
            "answer": str(highest_mean),
         },
]

}
check_solution(proposed_solution)
# Out:
# |                    Task Name                     |       Status       |
# |--------------------------------------------------|--------------------|
# |--------------------------------------------------|--------------------|
# |                 victoria secret                  |      Correct       |
# |--------------------------------------------------|--------------------|
# |                price unification                 |     Incorrect      |
# |--------------------------------------------------|--------------------|
# |                   highest mean                   |     Incorrect      |
# |--------------------------------------------------|--------------------|
